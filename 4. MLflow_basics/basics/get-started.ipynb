# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://localhost:5000")

# %%
mlflow.set_experiment("localhost-connection")

with mlflow.start_run():
    mlflow.log_metric("test", 1)
    mlflow.log_metric("subh", 2)
# Out:
# 2025/11/03 15:42:48 INFO mlflow.tracking.fluent: Experiment with name 'localhost-connection' does not exist. Creating a new experiment.
# 🏃 View run unequaled-horse-591 at: http://localhost:5000/#/experiments/434201400935416796/runs/8545fbbf5b7e4f4280f768d22beb29e0
# 🧪 View experiment at: http://localhost:5000/#/experiments/434201400935416796
